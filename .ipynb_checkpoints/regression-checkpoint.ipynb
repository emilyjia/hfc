# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
team_count = 22
teams = range(team_count)
skill_count = 6
skills = range(skill_count)

# %%
uni_hind = pd.read_csv("uni_hind.csv", names = skills)
uni_day = pd.read_csv("uni_day.csv", names = skills)
#norm_hind = pd.read_csv("norm_hind.csv", names = skills)
#norm_day = pd.read_csv("norm_day.csv", names = skills)
#chunk_hind = pd.read_csv("chunk_hind.csv", names = skills)
#chunk_day = pd.read_csv("chunk_day.csv", names = skills)

# %%
team_skill = pd.read_csv("team_skill.csv", names = skills)

# %%
fig, axs = plt.subplots(2, 2, sharex = 'col', sharey = 'row')

# %%
def make_regression(assignment, out = "basic", graph = False, title=""):
    count = 0
    if out == "spec":
        rows = range(10, 22)
    elif out =="div":
        rows = range(10)
    else:
        rows = teams
    regression = pd.DataFrame(index=range(len(rows)*skill_count), columns = ["assign", "skill", "skill_type", "spec_skill", "spec"])
    for team in rows:
        for skill_type in skills:
            assign = assignment[skill_type].loc[team]
            skill = team_skill[skill_type].loc[team]
            if team > 9:
                spec_skill = skill
                spec = 1
            else:
                spec_skill = 0
                spec = 0
            regression.loc[count] = [assign, skill, skill_type, spec_skill, spec]
            count+=1
    y = regression["assign"]  
    hue = regression["skill_type"]
    if out == "compare":
        x_spec = regression[["skill", "spec_skill", "spec"]]
        model_spec = sm.OLS(y.astype(float),x_spec.astype(float)).fit()
        predictions_spec = model_spec.predict(x_spec.astype(float))
        return model_spec
    else:
        x_basic = regression["skill"]
        model_basic = sm.OLS(y.astype(float),x_basic.astype(float)).fit()
        predictions_basic = model_basic.predict(x_basic.astype(float))
        if graph==True:
            graph = sns.lmplot(x='skill', y='assign', hue='skill_type', data=regression, fit_reg=False)
            # sns.regplot(x='skill', y='assign', data=regression, scatter=False)
            sns.regplot(x_basic.astype(float),y.astype(float),scatter=False, ax=graph.axes[0, 0]).set_title(title)
        else:
            return model_basic

# %%
make_regression(uni_hind,"basic", True, "uniformly distributed tasks, hind")

# %%
make_regression(uni_hind).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     24.43
# Date:                Tue, 17 Apr 2018   Prob (F-statistic):           2.31e-06
# Time:                        16:20:30   Log-Likelihood:                 203.75
# No. Observations:                 132   AIC:                            -405.5
# Df Residuals:                     131   BIC:                            -402.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          0.0045      0.001      4.943      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                       42.395   Durbin-Watson:                   0.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.321
# Skew:                           0.206   Prob(JB):                       0.0156
# Kurtosis:                       1.841   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
make_regression(uni_day,"basic", True, "uniformly distributed tasks, day")

# %%
make_regression(uni_day).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8313
# Date:                Sat, 28 Apr 2018   Prob (F-statistic):              0.364
# Time:                        16:10:16   Log-Likelihood:                -848.66
# No. Observations:                 132   AIC:                             1699.
# Df Residuals:                     131   BIC:                             1702.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          2.3846      2.615      0.912      0.364      -2.789       7.558
# ==============================================================================
# Omnibus:                        2.955   Durbin-Watson:                   0.019
# Prob(Omnibus):                  0.228   Jarque-Bera (JB):                2.843
# Skew:                          -0.357   Prob(JB):                        0.241
# Kurtosis:                       2.924   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
make_regression(norm_hind, "basic", True, "normal, hindsight")

# %%
make_regression(norm_hind).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     19.44
# Date:                Tue, 17 Apr 2018   Prob (F-statistic):           2.14e-05
# Time:                        16:20:31   Log-Likelihood:                 202.18
# No. Observations:                 132   AIC:                            -402.4
# Df Residuals:                     131   BIC:                            -399.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          0.0040      0.001      4.409      0.000       0.002       0.006
# ==============================================================================
# Omnibus:                       29.279   Durbin-Watson:                   0.520
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.286
# Skew:                           0.303   Prob(JB):                       0.0159
# Kurtosis:                       1.932   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
make_regression(norm_day, "basic", True, "normal, day, div")

# %%
make_regression(norm_day).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6439
# Date:                Tue, 17 Apr 2018   Prob (F-statistic):              0.424
# Time:                        16:20:31   Log-Likelihood:                 220.81
# No. Observations:                 132   AIC:                            -439.6
# Df Residuals:                     131   BIC:                            -436.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          0.0006      0.001      0.802      0.424      -0.001       0.002
# ==============================================================================
# Omnibus:                        8.698   Durbin-Watson:                   0.019
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.512
# Skew:                          -0.594   Prob(JB):                       0.0142
# Kurtosis:                       3.371   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
make_regression(chunk_hind, "basic", True, "chunk, hindsight")

# %%
make_regression(chunk_hind).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     24.66
# Date:                Tue, 17 Apr 2018   Prob (F-statistic):           2.09e-06
# Time:                        16:20:32   Log-Likelihood:                 203.98
# No. Observations:                 132   AIC:                            -406.0
# Df Residuals:                     131   BIC:                            -403.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          0.0045      0.001      4.965      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                       25.341   Durbin-Watson:                   0.569
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.678
# Skew:                           0.285   Prob(JB):                       0.0215
# Kurtosis:                       1.965   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
make_regression(chunk_day, "spec", True, "chunk, day, spec")

# %%
make_regression(chunk_day).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 assign   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6577
# Date:                Tue, 17 Apr 2018   Prob (F-statistic):              0.419
# Time:                        16:20:33   Log-Likelihood:                 220.89
# No. Observations:                 132   AIC:                            -439.8
# Df Residuals:                     131   BIC:                            -436.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# skill          0.0006      0.001      0.811      0.419      -0.001       0.002
# ==============================================================================
# Omnibus:                       16.444   Durbin-Watson:                   0.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.658
# Skew:                          -0.762   Prob(JB):                     5.39e-05
# Kurtosis:                       4.119   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
